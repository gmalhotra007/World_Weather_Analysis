# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

clean_hotel_df = pd.read_csv("/Users/gnrkaur/Desktop/Development/Module6/World_Weather_Analysis/Vacation_Search/hotels.csv")
clean_hotel_df
# Out:
#      City_ID             City Country  Max Temp Current Description    Lat  \
# 0          2  Arraial Do Cabo      BR     82.40           clear sky -22.97
# 1          6     Saint-Pierre      RE     75.20    scattered clouds -21.34
# 2          9             Gabu      GW     79.72       broken clouds  12.28
# 3         11          Samarai      PG     81.14       broken clouds -10.62
# 4         13           Avarua      CK     80.60       moderate rain -21.21
# ..       ...              ...     ...       ...                 ...    ...
# 190      650        Porbandar      IN     76.12           clear sky  21.64
# 191      652           Xuddur      SO     78.39           clear sky   4.12
# 192      655        Dhidhdhoo      MV     83.03          few clouds   6.88
# 193      659       Vianopolis      BR     75.56       broken clouds -16.74
# 194      663     Boca Do Acre      BR     92.91     overcast clouds  -8.75
#
#         Lng           Hotel Name
# 0    -42.03  Pousada Porto Praia
# ...

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("/Users/gnrkaur/Desktop/Development/Module6/World_Weather_Analysis/Vacation_Search/hotels.csv")
vacation_df.loc[vacation_df["Country"] == 'BR']
# Out:
#      City_ID                       City Country  Max Temp  \
# 0          2            Arraial Do Cabo      BR     82.40
# 12        56               Luis Correia      BR     83.17
# 21        80                 Correntina      BR     78.33
# 32       101                     Castro      BR     78.03
# 39       124   Sao Jose Da Coroa Grande      BR     78.44
# 47       148                  Piacabucu      BR     78.60
# 55       179                     Olinda      BR     80.60
# 56       183                      Natal      BR     84.20
# 60       204                    Itarema      BR     82.11
# 65       232                  Caravelas      BR     77.52
# 72       258                    Perdoes      BR     77.59
# 75       275         Sao Felix Do Xingu      BR     85.86
# 77       279                       Tefe      BR     89.60
# 78       281                      Borba      BR     92.52
# 79       282                    Pitimbu      BR     82.40
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Arraial Do Cabo"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Arraial Do Cabo"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Luis Correia"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Correntina"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Castro"]  

vacation_start
# Out:
#    City_ID             City Country  Max Temp Current Description    Lat  \
# 0        2  Arraial Do Cabo      BR      82.4           clear sky -22.97
#
#      Lng           Hotel Name
# 0 -42.03  Pousada Porto Praia

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (-22.97,-42.03)
end = (1-22.97,-42.03)
stop1 = (-2.88,-41.67)
stop2 = (-13.34,-44.64)
stop3 = (-24.79,-50.01)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig= gmaps.figure()
start2end_via_waypoints = gmaps.directions_layer(start,end,waypoints=[stop1,stop2,stop3], travel_mode='DRIVING')
fig.add_layer(start2end_via_waypoints)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID             City Country  Max Temp   Current Description    Lat  \
# 0        2  Arraial Do Cabo      BR     82.40             clear sky -22.97
# 1       56     Luis Correia      BR     83.17             clear sky  -2.88
# 2       80       Correntina      BR     78.33       overcast clouds -13.34
# 3      101           Castro      BR     78.03  heavy intensity rain -24.79
#
#      Lng                Hotel Name
# 0 -42.03       Pousada Porto Praia
# 1 -41.67           Hotel Amarração
# 2 -44.64  Hotel Pousada dos Sonhos
# 3 -50.01            CHACARA BAILLY

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(-13.0, -44.0), zoom_level=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# marker_layer
# fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
