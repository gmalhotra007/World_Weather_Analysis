# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import gmaps

from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from config import g_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key = g_key)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=251616b2d4863150b9fb7bff3bc004e4

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #Get rain information
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        
        #Get snow information
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | nemuro
# Processing Record 6 of Set 1 | sao filipe
# Processing Record 7 of Set 1 | saint-pierre
# Processing Record 8 of Set 1 | witrivier
# City not found. Skipping...
# Processing Record 9 of Set 1 | kutum
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | gabu
# Processing Record 12 of Set 1 | novoilinskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | tignere
# Processing Record 14 of Set 1 | samarai
# Processing Record 15 of Set 1 | kayerkan
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | luan
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | brae
# Processing Record 25 of Set 1 | abnub
# Processing Record 26 of Set 1 | beloha
# Processing Record 27 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | freeport
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | ulaangom
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | beringovskiy
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | jinxiang
# Processing Record 38 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 1 | manado
# Processing Record 40 of Set 1 | sisimiut
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | mandiana
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | pimentel
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | moree
# Processing Record 2 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | pak phanang
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | caluquembe
# Processing Record 9 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | izhma
# Processing Record 12 of Set 2 | raduzhnyy
# Processing Record 13 of Set 2 | ilmenau
# Processing Record 14 of Set 2 | nouadhibou
# Processing Record 15 of Set 2 | jumla
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | limon
# Processing Record 18 of Set 2 | luis correia
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | port lincoln
# Processing Record 24 of Set 2 | iskateley
# Processing Record 25 of Set 2 | anadyr
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | oktyabrskoye
# Processing Record 28 of Set 2 | avera
# Processing Record 29 of Set 2 | champerico
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | garowe
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | ola
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | menongue
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | correntina
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | labuhan
# Processing Record 46 of Set 2 | omboue
# Processing Record 47 of Set 2 | harper
# Processing Record 48 of Set 2 | pochutla
# Processing Record 49 of Set 2 | witham
# Processing Record 50 of Set 2 | austin
# Processing Record 1 of Set 3 | bandarbeyla
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | pierre
# Processing Record 4 of Set 3 | gulu
# Processing Record 5 of Set 3 | pandaria
# Processing Record 6 of Set 3 | krasnorechenskiy
# Processing Record 7 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | taltal
# Processing Record 11 of Set 3 | kavarskas
# Processing Record 12 of Set 3 | san luis
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | dakar
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | waycross
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | uhlove
# Processing Record 22 of Set 3 | sabang
# Processing Record 23 of Set 3 | kenai
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | megion
# Processing Record 26 of Set 3 | tahoua
# Processing Record 27 of Set 3 | lyman
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | hofn
# Processing Record 33 of Set 3 | bhatkal
# Processing Record 34 of Set 3 | nirsa
# Processing Record 35 of Set 3 | novoomskiy
# Processing Record 36 of Set 3 | prokhorovka
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | sumenep
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | sao jose da coroa grande
# Processing Record 42 of Set 3 | tondano
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | sinnar
# Processing Record 45 of Set 3 | lima
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | billings
# Processing Record 50 of Set 3 | nantucket
# Processing Record 1 of Set 4 | saint-augustin
# Processing Record 2 of Set 4 | mangrol
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | saint anthony
# Processing Record 5 of Set 4 | aksarka
# Processing Record 6 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 4 | bireun
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | jadu
# Processing Record 11 of Set 4 | grand gaube
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | hovd
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 4 | puerto colombia
# Processing Record 19 of Set 4 | piacabucu
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | margate
# Processing Record 23 of Set 4 | mosquera
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | port hawkesbury
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | ratnagiri
# Processing Record 29 of Set 4 | kytmanovo
# Processing Record 30 of Set 4 | banepa
# Processing Record 31 of Set 4 | yulara
# Processing Record 32 of Set 4 | medicine hat
# Processing Record 33 of Set 4 | lethem
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | east london
# Processing Record 36 of Set 4 | mason city
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | souillac
# Processing Record 41 of Set 4 | hanting
# Processing Record 42 of Set 4 | sibu
# Processing Record 43 of Set 4 | coos bay
# Processing Record 44 of Set 4 | mahajanga
# Processing Record 45 of Set 4 | halifax
# Processing Record 46 of Set 4 | port blair
# Processing Record 47 of Set 4 | kruisfontein
# Processing Record 48 of Set 4 | merauke
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | olinda
# Processing Record 2 of Set 5 | upernavik
# Processing Record 3 of Set 5 | mosetse
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | natal
# Processing Record 6 of Set 5 | iskitim
# Processing Record 7 of Set 5 | klyuchi
# Processing Record 8 of Set 5 | stykkisholmur
# Processing Record 9 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 5 | fort abbas
# Processing Record 11 of Set 5 | hilo
# Processing Record 12 of Set 5 | rio gallegos
# Processing Record 13 of Set 5 | whitehorse
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | garden city
# Processing Record 16 of Set 5 | turochak
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | kilinochchi
# Processing Record 20 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 5 | sakakah
# Processing Record 22 of Set 5 | pacific grove
# Processing Record 23 of Set 5 | taree
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | port alfred
# Processing Record 28 of Set 5 | itarema
# Processing Record 29 of Set 5 | surt
# Processing Record 30 of Set 5 | kloulklubed
# Processing Record 31 of Set 5 | arman
# Processing Record 32 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 33 of Set 5 | whitehaven
# Processing Record 34 of Set 5 | moerai
# Processing Record 35 of Set 5 | camacha
# Processing Record 36 of Set 5 | panama city
# Processing Record 37 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 5 | linxia
# Processing Record 39 of Set 5 | nelson bay
# Processing Record 40 of Set 5 | channel-port aux basques
# Processing Record 41 of Set 5 | omsukchan
# Processing Record 42 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 5 | lukow
# Processing Record 44 of Set 5 | yumen
# Processing Record 45 of Set 5 | metro
# Processing Record 46 of Set 5 | lidingo
# Processing Record 47 of Set 5 | outlook
# Processing Record 48 of Set 5 | nuuk
# Processing Record 49 of Set 5 | alekseyevka
# Processing Record 50 of Set 5 | north battleford
# Processing Record 1 of Set 6 | yeppoon
# Processing Record 2 of Set 6 | zhigalovo
# Processing Record 3 of Set 6 | harer
# Processing Record 4 of Set 6 | norsup
# Processing Record 5 of Set 6 | muros
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | george town
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | caravelas
# Processing Record 10 of Set 6 | samana
# Processing Record 11 of Set 6 | ponta delgada
# Processing Record 12 of Set 6 | talnakh
# Processing Record 13 of Set 6 | banda aceh
# Processing Record 14 of Set 6 | fort walton beach
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | fort nelson
# Processing Record 17 of Set 6 | santo tomas
# Processing Record 18 of Set 6 | yerbogachen
# Processing Record 19 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | cockburn town
# Processing Record 22 of Set 6 | shaunavon
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | noumea
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | diffa
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | taksimo
# Processing Record 29 of Set 6 | kazachka
# Processing Record 30 of Set 6 | zabaykalsk
# Processing Record 31 of Set 6 | coihaique
# Processing Record 32 of Set 6 | hirara
# Processing Record 33 of Set 6 | jiayuguan
# Processing Record 34 of Set 6 | churapcha
# Processing Record 35 of Set 6 | khorixas
# Processing Record 36 of Set 6 | fortuna
# Processing Record 37 of Set 6 | perdoes
# Processing Record 38 of Set 6 | port elizabeth
# Processing Record 39 of Set 6 | praya
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | zhigansk
# Processing Record 43 of Set 6 | pontianak
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | rafaela
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | college
# Processing Record 48 of Set 6 | kynashiv
# Processing Record 49 of Set 6 | kibala
# Processing Record 50 of Set 6 | spencer
# Processing Record 1 of Set 7 | lufilufi
# Processing Record 2 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 7 | saint-francois
# Processing Record 4 of Set 7 | luderitz
# Processing Record 5 of Set 7 | sao felix do xingu
# Processing Record 6 of Set 7 | nenjiang
# Processing Record 7 of Set 7 | neuquen
# Processing Record 8 of Set 7 | port hardy
# Processing Record 9 of Set 7 | tefe
# Processing Record 10 of Set 7 | wolsztyn
# Processing Record 11 of Set 7 | borba
# Processing Record 12 of Set 7 | pitimbu
# Processing Record 13 of Set 7 | faya
# Processing Record 14 of Set 7 | uk
# City not found. Skipping...
# Processing Record 15 of Set 7 | sept-iles
# Processing Record 16 of Set 7 | koumac
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | bayir
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | kosonsoy
# Processing Record 21 of Set 7 | tigzirt
# Processing Record 22 of Set 7 | umm lajj
# Processing Record 23 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 7 | zhezkazgan
# Processing Record 25 of Set 7 | brindisi
# Processing Record 26 of Set 7 | sulangan
# Processing Record 27 of Set 7 | andreyevo
# Processing Record 28 of Set 7 | waipawa
# Processing Record 29 of Set 7 | rocha
# Processing Record 30 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 7 | victoria
# Processing Record 33 of Set 7 | korla
# Processing Record 34 of Set 7 | kasama
# Processing Record 35 of Set 7 | tautira
# Processing Record 36 of Set 7 | bathsheba
# Processing Record 37 of Set 7 | homer
# Processing Record 38 of Set 7 | mmabatho
# Processing Record 39 of Set 7 | sheridan
# Processing Record 40 of Set 7 | goma
# Processing Record 41 of Set 7 | new milford
# Processing Record 42 of Set 7 | eureka
# Processing Record 43 of Set 7 | bintulu
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | hashtrud
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 7 | high level
# Processing Record 49 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 7 | ahipara
# Processing Record 1 of Set 8 | tripoli
# Processing Record 2 of Set 8 | berdigestyakh
# Processing Record 3 of Set 8 | goundam
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | anito
# Processing Record 6 of Set 8 | bologoye
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | abu kamal
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | necochea
# Processing Record 11 of Set 8 | parabel
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | ryotsu
# Processing Record 14 of Set 8 | alta floresta
# Processing Record 15 of Set 8 | kinarut
# Processing Record 16 of Set 8 | tilichiki
# Processing Record 17 of Set 8 | namtsy
# Processing Record 18 of Set 8 | san vicente
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | aden
# Processing Record 21 of Set 8 | onguday
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | lavumisa
# Processing Record 25 of Set 8 | timbiqui
# Processing Record 26 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 8 | geraldton
# Processing Record 28 of Set 8 | thunder bay
# Processing Record 29 of Set 8 | plainview
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 8 | mugumu
# Processing Record 34 of Set 8 | rajauri
# Processing Record 35 of Set 8 | puro
# Processing Record 36 of Set 8 | ngorongoro
# Processing Record 37 of Set 8 | pedernales
# Processing Record 38 of Set 8 | suao
# City not found. Skipping...
# Processing Record 39 of Set 8 | sola
# Processing Record 40 of Set 8 | san jeronimo
# Processing Record 41 of Set 8 | stornoway
# Processing Record 42 of Set 8 | salta
# Processing Record 43 of Set 8 | kushima
# Processing Record 44 of Set 8 | dobryanka
# Processing Record 45 of Set 8 | rio branco do sul
# Processing Record 46 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 8 | kousseri
# Processing Record 48 of Set 8 | mingyue
# Processing Record 49 of Set 8 | huambo
# Processing Record 50 of Set 8 | veraval
# Processing Record 1 of Set 9 | amapa
# Processing Record 2 of Set 9 | warwick
# Processing Record 3 of Set 9 | zelenoborskiy
# Processing Record 4 of Set 9 | lingyuan
# Processing Record 5 of Set 9 | hobyo
# Processing Record 6 of Set 9 | safety harbor
# Processing Record 7 of Set 9 | paso de los toros
# Processing Record 8 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | san francisco
# Processing Record 12 of Set 9 | kirsanov
# Processing Record 13 of Set 9 | west wendover
# Processing Record 14 of Set 9 | santo antonio do sudoeste
# Processing Record 15 of Set 9 | ilulissat
# Processing Record 16 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 9 | qurayyat
# Processing Record 18 of Set 9 | presidencia roque saenz pena
# Processing Record 19 of Set 9 | helena
# Processing Record 20 of Set 9 | ancud
# Processing Record 21 of Set 9 | aswan
# Processing Record 22 of Set 9 | iranshahr
# Processing Record 23 of Set 9 | mumbwa
# Processing Record 24 of Set 9 | jiexiu
# Processing Record 25 of Set 9 | cidreira
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | alyangula
# Processing Record 28 of Set 9 | beni mazar
# Processing Record 29 of Set 9 | varberg
# Processing Record 30 of Set 9 | taoudenni
# Processing Record 31 of Set 9 | san andres
# Processing Record 32 of Set 9 | cieza
# Processing Record 33 of Set 9 | broken hill
# Processing Record 34 of Set 9 | muzhi
# Processing Record 35 of Set 9 | floro
# Processing Record 36 of Set 9 | aklavik
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | aktash
# Processing Record 39 of Set 9 | vila franca do campo
# Processing Record 40 of Set 9 | miraflores
# Processing Record 41 of Set 9 | aviles
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | malakal
# Processing Record 44 of Set 9 | baiyin
# Processing Record 45 of Set 9 | ardino
# Processing Record 46 of Set 9 | amga
# Processing Record 47 of Set 9 | pocoes
# Processing Record 48 of Set 9 | havoysund
# Processing Record 49 of Set 9 | henties bay
# Processing Record 50 of Set 9 | tottori
# Processing Record 1 of Set 10 | polignano a mare
# Processing Record 2 of Set 10 | panaba
# Processing Record 3 of Set 10 | chakulia
# Processing Record 4 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 10 | asau
# Processing Record 6 of Set 10 | french harbor
# Processing Record 7 of Set 10 | benicarlo
# Processing Record 8 of Set 10 | trairi
# Processing Record 9 of Set 10 | blanes
# Processing Record 10 of Set 10 | marsh harbour
# Processing Record 11 of Set 10 | bonavista
# Processing Record 12 of Set 10 | zaqatala
# Processing Record 13 of Set 10 | mwene-ditu
# Processing Record 14 of Set 10 | tres arroyos
# Processing Record 15 of Set 10 | urambo
# Processing Record 16 of Set 10 | kikwit
# Processing Record 17 of Set 10 | aripuana
# Processing Record 18 of Set 10 | pouembout
# Processing Record 19 of Set 10 | cajamarca
# Processing Record 20 of Set 10 | thinadhoo
# Processing Record 21 of Set 10 | uyuni
# Processing Record 22 of Set 10 | marzuq
# Processing Record 23 of Set 10 | presidente medici
# Processing Record 24 of Set 10 | abadiania
# Processing Record 25 of Set 10 | general pico
# Processing Record 26 of Set 10 | teguldet
# Processing Record 27 of Set 10 | cosala
# Processing Record 28 of Set 10 | goure
# Processing Record 29 of Set 10 | leningradskiy
# Processing Record 30 of Set 10 | dudinka
# Processing Record 31 of Set 10 | rosetta
# Processing Record 32 of Set 10 | puerto del rosario
# Processing Record 33 of Set 10 | bissau
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | san cristobal
# Processing Record 36 of Set 10 | mana
# Processing Record 37 of Set 10 | maragogi
# Processing Record 38 of Set 10 | svetlogorsk
# Processing Record 39 of Set 10 | toora-khem
# Processing Record 40 of Set 10 | yamada
# Processing Record 41 of Set 10 | sao sebastiao
# Processing Record 42 of Set 10 | olafsvik
# Processing Record 43 of Set 10 | burnie
# Processing Record 44 of Set 10 | poum
# Processing Record 45 of Set 10 | mitsamiouli
# Processing Record 46 of Set 10 | beira
# Processing Record 47 of Set 10 | verkhnevilyuysk
# Processing Record 48 of Set 10 | resistencia
# Processing Record 49 of Set 10 | santa maria
# Processing Record 50 of Set 10 | kiunga
# Processing Record 1 of Set 11 | calca
# Processing Record 2 of Set 11 | puerto lempira
# Processing Record 3 of Set 11 | santa cruz
# Processing Record 4 of Set 11 | ilheus
# Processing Record 5 of Set 11 | pisco
# Processing Record 6 of Set 11 | severo-kurilsk
# Processing Record 7 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 11 | ayan
# Processing Record 9 of Set 11 | bend
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | cabo san lucas
# Processing Record 12 of Set 11 | samfya
# Processing Record 13 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 11 | jiaojiang
# Processing Record 15 of Set 11 | cochabamba
# Processing Record 16 of Set 11 | tessalit
# Processing Record 17 of Set 11 | seda
# Processing Record 18 of Set 11 | asfi
# Processing Record 19 of Set 11 | manokwari
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | lompoc
# Processing Record 22 of Set 11 | zaysan
# Processing Record 23 of Set 11 | djenne
# Processing Record 24 of Set 11 | dubuque
# Processing Record 25 of Set 11 | bosaso
# Processing Record 26 of Set 11 | gamba
# Processing Record 27 of Set 11 | daru
# Processing Record 28 of Set 11 | karratha
# Processing Record 29 of Set 11 | platteville
# Processing Record 30 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 31 of Set 11 | luwuk
# Processing Record 32 of Set 11 | saint-georges
# Processing Record 33 of Set 11 | porto novo
# Processing Record 34 of Set 11 | fernley
# Processing Record 35 of Set 11 | khani
# Processing Record 36 of Set 11 | kiruna
# Processing Record 37 of Set 11 | ketchikan
# Processing Record 38 of Set 11 | gat
# Processing Record 39 of Set 11 | laje
# Processing Record 40 of Set 11 | belyy yar
# Processing Record 41 of Set 11 | roald
# Processing Record 42 of Set 11 | komsomolskiy
# Processing Record 43 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 44 of Set 11 | aktau
# Processing Record 45 of Set 11 | havelock
# Processing Record 46 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 11 | longido
# Processing Record 48 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 11 | motygino
# Processing Record 50 of Set 11 | ostrovnoy
# Processing Record 1 of Set 12 | akcakoca
# Processing Record 2 of Set 12 | mineiros
# Processing Record 3 of Set 12 | walvis bay
# Processing Record 4 of Set 12 | lumeje
# Processing Record 5 of Set 12 | kasimov
# Processing Record 6 of Set 12 | vanimo
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | cordoba
# Processing Record 9 of Set 12 | manoel urbano
# Processing Record 10 of Set 12 | oranjemund
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | wasilla
# Processing Record 13 of Set 12 | bangolo
# Processing Record 14 of Set 12 | belmonte
# Processing Record 15 of Set 12 | nanortalik
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | kalaleh
# Processing Record 18 of Set 12 | tiksi
# Processing Record 19 of Set 12 | heishan
# Processing Record 20 of Set 12 | sirsa
# Processing Record 21 of Set 12 | inuvik
# Processing Record 22 of Set 12 | anshun
# Processing Record 23 of Set 12 | bangalore
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | kirakira
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | krasnokamensk
# Processing Record 28 of Set 12 | port hedland
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | duz
# City not found. Skipping...
# Processing Record 31 of Set 12 | shenjiamen
# Processing Record 32 of Set 12 | kavaratti
# Processing Record 33 of Set 12 | macklin
# Processing Record 34 of Set 12 | zawiyat susah
# City not found. Skipping...
# Processing Record 35 of Set 12 | los llanos de aridane
# Processing Record 36 of Set 12 | naron
# Processing Record 37 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 38 of Set 12 | dashitou
# Processing Record 39 of Set 12 | wernigerode
# Processing Record 40 of Set 12 | vila
# Processing Record 41 of Set 12 | egvekinot
# Processing Record 42 of Set 12 | fare
# Processing Record 43 of Set 12 | tiznit
# Processing Record 44 of Set 12 | warora
# Processing Record 45 of Set 12 | kudahuvadhoo
# Processing Record 46 of Set 12 | port antonio
# Processing Record 47 of Set 12 | najran
# Processing Record 48 of Set 12 | verkhovazhye
# Processing Record 49 of Set 12 | grobina
# Processing Record 50 of Set 12 | praia
# Processing Record 1 of Set 13 | manta
# Processing Record 2 of Set 13 | ambon
# Processing Record 3 of Set 13 | darhan
# Processing Record 4 of Set 13 | oriximina
# Processing Record 5 of Set 13 | tabuk
# Processing Record 6 of Set 13 | atka
# City not found. Skipping...
# Processing Record 7 of Set 13 | amos
# Processing Record 8 of Set 13 | kununurra
# Processing Record 9 of Set 13 | novonukutskiy
# Processing Record 10 of Set 13 | flinders
# Processing Record 11 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 13 | buala
# Processing Record 13 of Set 13 | upata
# Processing Record 14 of Set 13 | barra do corda
# Processing Record 15 of Set 13 | kismayo
# Processing Record 16 of Set 13 | itoman
# Processing Record 17 of Set 13 | haines junction
# Processing Record 18 of Set 13 | tazovskiy
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | meulaboh
# Processing Record 21 of Set 13 | sira
# Processing Record 22 of Set 13 | berlevag
# Processing Record 23 of Set 13 | santa maria del oro
# Processing Record 24 of Set 13 | esso
# Processing Record 25 of Set 13 | acapulco
# Processing Record 26 of Set 13 | jaque
# Processing Record 27 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 28 of Set 13 | pacifica
# Processing Record 29 of Set 13 | curaca
# Processing Record 30 of Set 13 | sroda wielkopolska
# Processing Record 31 of Set 13 | bobo dioulasso
# Processing Record 32 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 13 | goderich
# Processing Record 34 of Set 13 | okhotsk
# Processing Record 35 of Set 13 | sonqor
# Processing Record 36 of Set 13 | atikokan
# Processing Record 37 of Set 13 | kanye
# Processing Record 38 of Set 13 | ajdabiya
# Processing Record 39 of Set 13 | hanna
# Processing Record 40 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 13 | belturbet
# Processing Record 42 of Set 13 | williams lake
# Processing Record 43 of Set 13 | hamilton
# Processing Record 44 of Set 13 | calahorra
# Processing Record 45 of Set 13 | minnedosa
# Processing Record 46 of Set 13 | tiebissou
# Processing Record 47 of Set 13 | olden
# Processing Record 48 of Set 13 | teya
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | nuevo ideal
# Processing Record 1 of Set 14 | sakaiminato
# Processing Record 2 of Set 14 | acarau
# Processing Record 3 of Set 14 | culipapa
# City not found. Skipping...
# Processing Record 4 of Set 14 | linden
# Processing Record 5 of Set 14 | nevelsk
# Processing Record 6 of Set 14 | griffith
# Processing Record 7 of Set 14 | antofagasta
# Processing Record 8 of Set 14 | huarmey
# Processing Record 9 of Set 14 | loandjili
# Processing Record 10 of Set 14 | suda
# Processing Record 11 of Set 14 | sal rei
# Processing Record 12 of Set 14 | cururupu
# Processing Record 13 of Set 14 | mabaruma
# Processing Record 14 of Set 14 | batagay-alyta
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | hopelchen
# Processing Record 17 of Set 14 | sobolevo
# Processing Record 18 of Set 14 | pala
# Processing Record 19 of Set 14 | wattegama
# Processing Record 20 of Set 14 | vagur
# Processing Record 21 of Set 14 | rawson
# Processing Record 22 of Set 14 | chimoio
# Processing Record 23 of Set 14 | lieksa
# Processing Record 24 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 14 | kharp
# Processing Record 26 of Set 14 | jiuquan
# Processing Record 27 of Set 14 | limbang
# Processing Record 28 of Set 14 | neftegorsk
# Processing Record 29 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 14 | port macquarie
# Processing Record 31 of Set 14 | hami
# Processing Record 32 of Set 14 | adrar
# Processing Record 33 of Set 14 | mnogovershinnyy
# Processing Record 34 of Set 14 | yenagoa
# Processing Record 35 of Set 14 | marawi
# Processing Record 36 of Set 14 | aranda de duero
# Processing Record 37 of Set 14 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 38 of Set 14 | bereznik
# Processing Record 39 of Set 14 | san julian
# Processing Record 40 of Set 14 | fort frances
# Processing Record 41 of Set 14 | punto fijo
# Processing Record 42 of Set 14 | san policarpo
# Processing Record 43 of Set 14 | aromashevo
# Processing Record 44 of Set 14 | nebbi
# Processing Record 45 of Set 14 | pucara
# Processing Record 46 of Set 14 | rastolita
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | la orilla
# Processing Record 49 of Set 14 | coro
# Processing Record 50 of Set 14 | tateyama
# Processing Record 1 of Set 15 | karasburg
# Processing Record 2 of Set 15 | bahir dar
# Processing Record 3 of Set 15 | georgiyevka
# Processing Record 4 of Set 15 | ous
# Processing Record 5 of Set 15 | guane
# Processing Record 6 of Set 15 | honningsvag
# Processing Record 7 of Set 15 | kasulu
# Processing Record 8 of Set 15 | dorado
# Processing Record 9 of Set 15 | la libertad
# Processing Record 10 of Set 15 | auki
# Processing Record 11 of Set 15 | woodstock
# Processing Record 12 of Set 15 | manggar
# Processing Record 13 of Set 15 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 14 of Set 15 | rundu
# Processing Record 15 of Set 15 | porbandar
# Processing Record 16 of Set 15 | ust-maya
# Processing Record 17 of Set 15 | xuddur
# Processing Record 18 of Set 15 | ler
# Processing Record 19 of Set 15 | verkhovyna
# Processing Record 20 of Set 15 | dhidhdhoo
# Processing Record 21 of Set 15 | moldava nad bodvou
# Processing Record 22 of Set 15 | ust-kuyga
# Processing Record 23 of Set 15 | shepsi
# Processing Record 24 of Set 15 | vianopolis
# Processing Record 25 of Set 15 | scarborough
# Processing Record 26 of Set 15 | kaseda
# Processing Record 27 of Set 15 | zeya
# Processing Record 28 of Set 15 | boca do acre
# Processing Record 29 of Set 15 | sunnyside
# Processing Record 30 of Set 15 | torata
# Processing Record 31 of Set 15 | hokitika
# Processing Record 32 of Set 15 | bembibre
# Processing Record 33 of Set 15 | oksfjord
# Processing Record 34 of Set 15 | mahon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.15  -70.92     55.40        54          75
# 1          Hualmay      PE -11.10  -77.61     71.19        69          52
# 2  Arraial Do Cabo      BR -22.97  -42.03     82.40        69           0
# 3           Dikson      RU  73.51   80.55     31.41        99         100
# 4           Nemuro      JP  43.32  145.57     33.51        88          23
#
#    Wind Speed Current Description
# 0       25.28       broken clouds
# 1       10.78       broken clouds
# 2       26.40           clear sky
# 3       27.11          light snow
# 4        8.99          few clouds

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
